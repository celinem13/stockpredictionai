# %% [markdown]
# # Stocks Update

# %% [markdown]
# Currently selling prices in Animal Crossing were low while buying price was very high. Coincidentally, Google's prices this week started off at a high buying price at around $2900. However, as the week progressed the price of Google's stocks rapidly dropped. I haven't sold any of the Google or game stocks yet. I'm going to wait to sell the turnip stocks on Saturday no matter what the price is. I'll have to wait on Monday to start trading in the Google stocks I have. Currently I haven't found the time to work on the AI to predict the turnip prices for Animal Crossing.

# %% [markdown]
# | Date | Morning Stalk Prices | Afternoon Stalk Prices | Time Bought | Date Bought| Stalk Buying Price | Amount of Stalk Bought | Time Sold | Date Sold | Stalk Selling Price | Amount of Stalk Sold | Total |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 11/20/2021 | 111 | 100 |NaN | NaN | NaN | NaN| NaN | NaN | NaN |NaN | 0 |
# | 11/21/2021 | NaN | NaN | 7:11 AM | 11/21/2021 | 108 | 4000 | NaN | NaN | NaN |NaN | -432000 |
# | 11/22/2021 | 89 | 86 | NaN | NaN | NaN | NaN | NaN | NaN | NaN |NaN | 0 |
# | 11/23/2021 | 72 | 76 | NaN | NaN | NaN | NaN | NaN | NaN | NaN |NaN | 0 |
# | 11/24/2021 | 70 | 69 | NaN | NaN | NaN | NaN | NaN | NaN | NaN |NaN | 0 |
# | 11/25/2021 | 74 | 60 | NaN | NaN | NaN | NaN | NaN | NaN| NaN | NaN | 0 |
# | 11/26/2021 | 53 | 59 | NaN | NaN | NaN | NaN | NaN | NaN | NaN |NaN | 0 |

# %% [markdown]
# ![Screenshot%202021-11-26%20193822.png](attachment:Screenshot%202021-11-26%20193822.png)

# %% [markdown]
# This screenshot is from https://ac-turnip.com/ where it predicts prices for the week as you input the data from each morning and afternoon. There were small spikes throughout the week but the random number generator was against me.

# %% [markdown]
# ![Screenshot%202021-11-26%20194709.png](attachment:Screenshot%202021-11-26%20194709.png)

# %% [markdown]
# This is the projected prediction of the week. With higher buying prices, turnips could possibly sell for more at a max of 990 bells. However, just like the Google stocks, the turnip prices fell fast.
